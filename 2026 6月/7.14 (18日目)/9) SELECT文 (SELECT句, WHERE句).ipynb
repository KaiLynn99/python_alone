# %%
# %pip install -U jupysql sqlalchemy "PyMySQL[rsa]"
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 10.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ------------------------ --------------- 2.4/3.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 10.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/707.6 kB ? eta -:--:--
#    ---------------------------------------- 707.6/707.6 kB 8.1 MB/s  0:00:00
# ...
#
#    -- -------------------------------------  1/19 [sqlparse]
#    ---- -----------------------------------  2/19 [sqlglot]
#    ---- -----------------------------------  2/19 [sqlglot]
#    ---- -----------------------------------  2/19 [sqlglot]
#    ---- -----------------------------------  2/19 [sqlglot]
#    ---- -----------------------------------  2/19 [sqlglot]
#    ---- -----------------------------------  2/19 [sqlglot]
# ...

# %%
# %load_ext sql

from db_connection import connect_sakila

engine = connect_sakila()
# %sql engine

# %config SqlMagic.autolimit = 10
# %config SqlMagic.displaylimit = 10
# %config SqlMagic.feedback = 0
# %config SqlMagic.displaycon = False
