# %%
orders = [
    {"注文番号": 1001, "顧客名": "김철수", "購入金額": 120000, "入会日": "2021-03-15", "地域": "서울"},
    {"注文番号": 1002, "顧客名": "이영희", "購入金額": None, "入会日": "2020-08-10", "地域": "부산"},
    {"注文番号": 1003, "顧客名": "박민수", "購入金額": 35000, "入会日": "2024-01-20", "地域": "서울"},
    {"注文番号": 1004, "顧客名": "최지은", "購入金額": -5000, "入会日": "2019-05-12", "地域": "대구"},
    {"注文番号": 1005, "顧客名": "정우성", "購入金額": 550000, "入会日": "2018-11-02", "地域": "서울"},
    {"注文番号": 1006, "顧客名": "한지민", "購入金額": None, "入会日": "2022-07-01", "地域": "부산"},
    {"注文番号": 1007, "顧客名": "강호동", "購入金額": 25000, "入会日": "2023-09-15", "地域": "광주"},
    {"注文番号": 1008, "顧客名": "신세경", "購入金額": 9999999, "入会日": "2021-12-24", "地域": "서울"},
    {"注文番号": 1009, "顧客名": "유재석", "購入金額": 89000, "入会日": "2020-01-05", "地域": "대전"},
    {"注文番号": 1010, "顧客名": "송혜교", "購入金額": 175000, "入会日": "2017-04-30", "地域": "서울"},
]

# %% [markdown]
# ### 問題1. 欠損値の確認
# 購入金額が欠損値（None）であるデータの個数を求めなさい。

# %%
missing_count

# %% [markdown]
# ### 問題2. 欠損値の処理
# 欠損値を除いた購入金額の平均を計算した後、欠損値をその平均値で置き換えなさい。

# %% [markdown]
# ### 問題3. 外れ値の検出
# 購入金額が（0〜1,000,000）の範囲を外れている場合、外れ値と判断する。

# %% [markdown]
# ### 問題4. 外れ値の処理
# 外れ値は次の基準で修正しなさい。
