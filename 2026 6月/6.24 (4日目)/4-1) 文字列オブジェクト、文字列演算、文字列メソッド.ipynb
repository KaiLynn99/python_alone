# %%
# Pythonの組み込みオブジェクトのうち、値だけを持つオブジェクト（数値、bool）はその値を変更できない。
# Pythonの文字列も変更できない。

s = "python"
print(s[0])
s[0] = "C" # error
# Out:
# p
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       2 # Pythonの文字列も変更できない。
#       3
#       4 s = "python"
#       5 print(s[0])
# ----> 6 s[0] = "C" # error
#
# TypeError: 'str' object does not support item assignment
