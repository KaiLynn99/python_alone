# %% [markdown]
# ## 1. 欠損値
#
# - 空文字 - トンボの英語、雫の国語、...
#
# - "欠損" - アシタカの国語、...
#
# - "NaN" - カンタの英語、...

# %%
import csv

missing_values = {"", "欠損", "NaN"}

with open("score.csv", "r", encoding="utf-8") as f:
    reader = csv.DictReader(f)

    for student in reader:
        if student[]
# Out:
# {'名前': '千尋', '年齢': '20', '国語': '90', '英語': '85'}
# {'名前': 'ハク', '年齢': '21', '国語': '88', '英語': '90'}
# {'名前': 'サン', '年齢': '', '国語': '95', '英語': '100'}
# {'名前': 'アシタカ', '年齢': '22', '国語': '欠損', '英語': '82'}
# {'名前': 'シータ', '年齢': '19', '国語': '100', '英語': '110'}
# {'名前': 'パズ', '年齢': '150', '国語': '85', '英語': '88'}
# {'名前': 'キキ', '年齢': '20', '国語': '-5', '英語': '91'}
# {'名前': 'トンボ', '年齢': '21', '国語': '92', '英語': ''}
# {'名前': 'ソフィー', '年齢': '18', '国語': '87', '英語': '89'}
# {'名前': 'ハウル', '年齢': '23', '国語': '93', '英語': '94'}
# {'名前': 'ナウシカ', '年齢': '20', '国語': '91', '英語': '86'}
# {'名前': 'アスベル', '年齢': '21', '国語': '89', '英語': '87'}
# {'名前': 'サツキ', '年齢': '22', '国語': '500', '英語': '92'}
# {'名前': 'メイ', '年齢': '19', '国語': '84', '英語': '81'}
# {'名前': 'カンタ', '年齢': '20', '国語': '86', '英語': 'NaN'}
# {'名前': '清太', '年齢': '21', '国語': '90', '英語': '88'}
# {'名前': '節子', '年齢': '22', '国語': '88', '英語': '85'}
# {'名前': '雫', '年齢': '20', '国語': '', '英語': '84'}
# {'名前': '聖司', '年齢': '19', '国語': '97', '英語': '96'}
# ...

# %%
import csv
missing_values = {"", "欠損", "nan"}

with open("score.csv", "r", encoding="utf-8") as f:
    reader = csv.DictReader(f)

    for student in reader:
        for column in ["年齢", "国語", "英語"]:
            value = student[column].strip()

            if value.lower() in missing_values:
                print(student["名前"], column, "欠損値")
# Out:
# サン 年齢 欠損値
# アシタカ 国語 欠損値
# トンボ 英語 欠損値
# カンタ 英語 欠損値
# 雫 国語 欠損値
