# %%
import pandas as pd

# 従業員データを作成
df = pd.DataFrame({
    '社員番号': [
        'E001', 'E002', 'E003', 'E004', 'E005',
        'E006', 'E007', 'E008', 'E009', 'E010',
        'E011', 'E012', 'E013', 'E014', 'E015',
        'E016', 'E017', 'E018', 'E019', 'E020',
        'E021', 'E022'
    ],

    '氏名': [
        '佐藤太郎', '鈴木花子', '高橋健太', '田中美咲', '伊藤さくら',
        '渡辺翔太', '山本彩', '中村大輔', '小林直樹', '加藤優奈',
        '吉田健', '山田葵', '佐々木蓮', '山口結衣', '松本拓也',
        '井上美月', '木村悠斗', '林陽菜', '清水颯太', '斎藤愛',
        '森大和', '池田凛'
    ],

    '部署': [
        '開発部', 'マーケティング部', '開発部', '人事部', '営業部',
        '開発部', 'マーケティング部', '営業部', '開発部', '人事部',
        '営業部', '開発部', 'マーケティング部', '営業部', '開発部',
        '人事部', 'マーケティング部', '開発部', '営業部', '開発部',
        'マーケティング部', '人事部'
    ],

    '性別': [
        '男', '女', '男', '女', '女',
        '男', '女', '男', '男', '女',
        '男', '女', '男', '女', '男',
        '女', '男', '女', '男', '女',
        '男', '女'
    ],

    '年齢': [
        28, 31, 26, 35, 29,
        42, 27, 33, 30, 38,
        45, 25, 34, 29, 41,
        32, 36, 28, 39, 27,
        44, 30
    ],

    '年収': [
        4200, 5100, 3900, 5800, 4500,
        7200, 4100, 5600, 4700, 6300,
        8100, 3800, 5900, 4400, 6900,
        5200, 6100, 4300, 6700, 4000,
        7600, 4800
    ],

    '勤続年数': [
        3, 5, 2, 8, 4,
        15, 2, 7, 5, 11,
        18, 1, 6, 3, 14,
        6, 9, 3, 12, 2,
        16, 5
    ],

    '評価ランク': [
        'A', 'B', 'A', 'C', 'B',
        'A', 'B', 'A', 'C', 'B',
        'A', 'A', 'B', 'C', 'A',
        'B', 'A', 'B', 'A', 'C',
        'A', 'B'
    ]
})

df
# Out:
#     社員番号     氏名        部署 性別  年齢    年収  勤続年数 評価ランク
# 0   E001   佐藤太郎       開発部  男  28  4200     3     A
# 1   E002   鈴木花子  マーケティング部  女  31  5100     5     B
# 2   E003   高橋健太       開発部  男  26  3900     2     A
# 3   E004   田中美咲       人事部  女  35  5800     8     C
# 4   E005  伊藤さくら       営業部  女  29  4500     4     B
# 5   E006   渡辺翔太       開発部  男  42  7200    15     A
# 6   E007    山本彩  マーケティング部  女  27  4100     2     B
# 7   E008   中村大輔       営業部  男  33  5600     7     A
# 8   E009   小林直樹       開発部  男  30  4700     5     C
# 9   E010   加藤優奈       人事部  女  38  6300    11     B
# 10  E011    吉田健       営業部  男  45  8100    18     A
# 11  E012    山田葵       開発部  女  25  3800     1     A
# 12  E013   佐々木蓮  マーケティング部  男  34  5900     6     B
# 13  E014   山口結衣       営業部  女  29  4400     3     C
# 14  E015   松本拓也       開発部  男  41  6900    14     A
# 15  E016   井上美月       人事部  女  32  5200     6     B
# 16  E017   木村悠斗  マーケティング部  男  36  6100     9     A
# ...

# %% [markdown]
# #### - 演習で使用するメソッドの整理
#
# `DataFrame 自体`に使用するもの
#
# ```python
# df.info()             # 全体の構造
# df.shape              # 行 × 列
# df.shape[0]           # 行数
# df.shape[1]           # 列数
# df.dtypes             # すべての列のデータ型
# df.columns            # 列名
# df.index              # インデックス
# df.head()             # 最初のデータ
# df.tail()             # 最後のデータ
# df.describe()         # 基本統計量
# df.count()            # 列ごとのデータ数
# df.isnull()           # 欠損値の有無
# df.isnull().sum()     # 欠損値の数
# df.duplicated()       # 重複の有無
# df.memory_usage()     # メモリ使用量
# ```

# %% [markdown]
# `特定の列` df['列'] に使用するもの
#
# ```py
# df['部署'].dtype           # データ型
# df['部署'].unique()        # ユニークな値
# df['部署'].nunique()       # ユニークな値の数
# df['部署'].value_counts()  # 値ごとの出現回数
# df['部署'].describe()      # 基本統計量
# df['部署'].isnull()        # 欠損値の有無
# df['部署'].astype()        # データ型を変換
# ```

# %% [markdown]
# #### 1. 基本構造（RangeIndex、Data columns、Non-Null Count、Dtype）を確認

# %% [markdown]
# #### 2. 行数、列数、列名の情報を確認

# %% [markdown]
# #### 3. ラベルインデックスを確認

# %% [markdown]
# #### 4. 各列のデータ型を確認

# %% [markdown]
# #### 5. 最初の3行、最後の3行のデータを確認

# %% [markdown]
# #### 6. 部署、性別、評価ランク列のユニーク値（unique）とユニーク値の数（nunique）を確認

# %% [markdown]
# #### 7. 部署、性別、評価ランク列の値ごとの出現回数（value_counts）を確認

# %% [markdown]
# #### 8. count、mean、std、min、25%、50%、75%、max の基本統計量を確認

# %% [markdown]
# #### 9. 数値型の特定列（年齢列）の基本統計量を確認

# %% [markdown]
# #### 10. 文字列型の特定列（部署列）の基本統計量を確認

# %% [markdown]
# #### 11. 性別をカテゴリ型データに変換
